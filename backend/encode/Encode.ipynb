# %%
from PIL import Image
import numpy as np 
import matplotlib.pyplot as plt

# %%
img = np.array(Image.open("./B1EXkZ2Em.jpeg"))
plt.imshow(img)

# %%
H,W, D= img.shape
H,W,D
# Out:
# (1280, 575, 3)

# %%
message = input()
message += '[END]'
message = message.encode("ascii")
message_bits = ''.join([format(i, '08b') for i in message])

# %%
message
message_bits
# Out:
# '010010110110010101101101011011110110111000100000010000010110001101101000011001010101101101000101010011100100010001011101'

# %%
img = img.flatten()
for idx, bit in enumerate(message_bits):
    val = img[idx]
    val = bin(val)
    val = val[:-1]+bit
    img[idx] = int(val,2)
img = img.reshape(H,W,D)

# %%
plt.imshow(img)

# %%
msg = ""
idx = 0
img = img.flatten()
while msg[-5:] != '[END]':
    bits = [bin(i)[-1] for i in img[idx:idx+8]]
    bits = "".join(bits)
    msg += chr(int(bits,2))
    idx += 8
    if idx > img.shape[0]-8:
        print("There is no hidden message")
        break
msg = msg[:-5]

# %%
msg
# Out:
# 'Kemon Ache'
